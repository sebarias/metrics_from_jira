# %%
import numpy as np
import pandas as pd
import cycle_time_analys as ana
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", palette = "pastel")
plt.style.use('seaborn') 
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
df = ana.get_issues_from('JET')
# Out:
# start at:  0

# %%
df
# Out:
#         key      id                                            summary  \
# 0   JET-421  474153                                    Configurar Jest
# 1   JET-413  470363                            Presentacion 1 Patrones
# 2   JET-408  470358                         Documentar creación de apk
# 3   JET-403  470353                                 Configurar Flipper
# 4   JET-397  470347                                 Documentar Flipper
# 5   JET-387  470337         Creacion repositorio proyecto general base
# 6   JET-386  470336         Discusion y definicion estructura proyecto
# 7   JET-385  470335                      Analisis  estructura proyecto
# 8   JET-384  467393           Documentacion y Presentacion POC Eventos
# 9   JET-381  464750  Back - POC Implementación Comunicación asíncro...
# 10  JET-379  461227            QA - Revisión fallados CP Automatizados
# 11  JET-378  461226                           QA - Pruebas Mi Pass MB3
# ...

# %%
df_sca = df.loc[:,['key','summary','story_points', 'lead_time','cycle_time','date_created','date_resolution','date_starting']]

# %%
df_sca
# Out:
#         key                                            summary  story_points  \
# 0   JET-421                                    Configurar Jest           2.0
# 1   JET-413                            Presentacion 1 Patrones           2.0
# 2   JET-408                         Documentar creación de apk           4.0
# 3   JET-403                                 Configurar Flipper           2.0
# 4   JET-397                                 Documentar Flipper           5.0
# 5   JET-387         Creacion repositorio proyecto general base           2.0
# 6   JET-386         Discusion y definicion estructura proyecto           3.0
# 7   JET-385                      Analisis  estructura proyecto           3.0
# 8   JET-384           Documentacion y Presentacion POC Eventos           3.0
# 9   JET-381  Back - POC Implementación Comunicación asíncro...           8.0
# 10  JET-379            QA - Revisión fallados CP Automatizados           5.0
# ...

# %%
df_sca['lead_time_int'] = df_sca['lead_time'].day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-ba8261809a23> in <module>
# ----> 1 df_sca['lead_time_int'] = df_sca['lead_time'].day
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'day'

# %%
plt.scatter(x='date_created',y='cycle_time',data=df_sca)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-679c7218c12c> in <module>
# ----> 1 plt.scatter(x='date_created',y='cycle_time',data=df_sca)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2876         verts=verts, edgecolors=edgecolors,
#    2877         plotnonfinite=plotnonfinite,
# -> 2878         **({"data": data} if data is not None else {}), **kwargs)
#    2879     sci(__ret)
#    2880     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1455                 args_and_kwargs.get(label_namer), auto_label)
#    1456
# -> 1457         return func(*new_args, **new_kwargs)
#    1458
# ...
